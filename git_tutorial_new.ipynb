# %%
print('I am a product analyst')
# Out:
# I am a product analyst

# %%
p_value = 0.05

user_input = float(input('Enter a number to see the statistical significance: '))

if user_input >= p_value:
  print('this is significant')
else:
  print('this is just noise')
# Out:
# Enter a number to see the statistical significance: 0.04
# this is just noise

# %%
job_title = 'Product Analyst'
salary_eur = 78500
skills = ['BigQuery','Python','Looker Studio','GCP','Amplitude']

print(f'Occupation: {job_title}\nSalary: €{salary_eur}\nKey Skills needed: {skills}')
# Out:
# Occupation: Product Analyst
# Salary: €78500
# Key Skills needed: ['BigQuery', 'Python', 'Looker Studio', 'GCP', 'Amplitude']
